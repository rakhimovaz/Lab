# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">Reading, saving, and displaying an image with OpenCV</div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# We start by importing the OpenCV package.
# </div>

# %%
import cv2

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/bin/python

# %%
import os
print(os.getcwd())
# Out:
# /Users/230104/Downloads

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import numpy as np

# %%
print (cv2.__version__)
# Out:
# 4.13.0

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/230104/.local/lib/python3.12/site-packages (4.13.0.90)
# Collecting numpy>=2 (from opencv-python)
#   Using cached numpy-2.4.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.2-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   WARNING: The scripts f2py and numpy-config are installed in '/Users/230104/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.4.2 which is incompatible.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.4.2 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.4.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.2 which is incompatible.
# Successfully installed numpy-2.4.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Let's now load our first image

# %%
# We don't need to do this again, but it's a good habit
import cv2

# Load an image using 'imread' specifying the path to image
img = cv2.imread('/content/drive/MyDrive/DIP/ai-image.jpg')

# The first parameter will be title shown on image window
# The second parameter is the image varialbe
cv2.imshow('It is an AI in Healthcare!', img)

# 'waitKey' allows us to input information when a image window is open
# By leaving it blank it just waits for anykey to be pressed before
# continuing. By placing numbers (except 0), we can specify a delay for
# how long you keep the window open (time is in milliseconds here)
cv2.waitKey()

# This closes all open windows
# Failure to place this may cause your program to hang in some computers!
cv2.destroyAllWindows()
# Out:
# [ WARN:0@192.261] global loadsave.cpp:278 findDecoder imread_('/content/drive/MyDrive/DIP/ai-image.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 9
#       5 img = cv2.imread('/content/drive/MyDrive/DIP/ai-image.jpg')
#       7 # The first parameter will be title shown on image window
#       8 # The second parameter is the image varialbe
# ----> 9 cv2.imshow('It is an AI in Healthcare!', img)
#      11 # 'waitKey' allows us to input information when a image window is open
#      12 # By leaving it blank it just waits for anykey to be pressed before
#      13 # continuing. By placing numbers (except 0), we can specify a delay for
#      14 # how long you keep the window open (time is in milliseconds here)
#      15 cv2.waitKey()
#
# error: OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/highgui/src/window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
# Same as above without the extraneous comments

import cv2

img = cv2.imread('/Users/230104/Documents/pink-piona-flower.jpg')

#cv2.imshow('It is a cow!', img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">How to save images in OpenCV</div>

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print (img.shape)
# Out:
# (900, 675, 3)

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">***shape*** shows the dimensions of the image.</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# The first two dimensions represent the height and width of the image, respectively. The number 3 indicates the presence of three color channels.
# </div>

# %%
# Let's print each dimension of the image

print ('Height of Image:', int(img.shape[0]), 'pixels')
print ('Width of Image: ', int(img.shape[1]), 'pixels')
# Out:
# Height of Image: 900 pixels
# Width of Image:  675 pixels

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">Saving images in OpenCV</div>

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('output.jpg', img)
cv2.imwrite('output.png', img)
# Out:
# True

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# ***True*** means that the operation was completed successfully.</div>

# %% [markdown]
# ### <div style="direction:ltr;text-align:left;font-family:Arial, Tahoma">Displaying in the Notebook with matplotlib</div>

# %%
import matplotlib.pyplot as plt

# %%
pip install 'numpy<2'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy<2
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
#   WARNING: The script f2py is installed in '/Users/230104/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.90 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.imshow(img)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# In fact, the rows and columns of the matrix correspond to the height and width of the image, respectively.<br/>
# The image colors appear inverted because the channel order in OpenCV is BGR, unlike most other libraries which use RGB.</div>

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">Changing the color channel order (BGR → RGB)</div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# Method 1: Using NumPy</div>

# %%
#method1
plt.imshow(img[:,:,::-1])

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# Method 2: Using OpenCV</div>

# %%
#method2
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">Modifying and manipulating pixels</div>

# %%
import cv2

img = cv2.imread('/Users/230104/Documents/pink-piona-flower.jpg')
img[200:500,300:600,:] = 255
plt.imshow(img[...,::-1])

# %%
img[200:300,300:500,:] = (0, 0, 255)
plt.imshow(img[...,::-1])
